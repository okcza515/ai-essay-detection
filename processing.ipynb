# %%
import pandas as pd

df = pd.read_csv('cleansed_sample.csv')

# %%
# Out:
# {'student': 1,
#  'car': 2,
#  'people': 3,
#  'would': 4,
#  'make': 5,
#  'school': 6,
#  'help': 7,
#  'get': 8,
#  'also': 9,
#  'time': 10,
#  'like': 11,
#  'one': 12,
#  'vote': 13,
#  'could': 14,
#  'electoral': 15,
#  'well': 16,
#  'use': 17,
#  'work': 18,
#  'go': 19,
#  'college': 20,
#  'take': 21,
#  'many': 22,
#  'think': 23,
#  'good': 24,
#  'way': 25,
#  'state': 26,
#  'learn': 27,
#  'need': 28,
#  'may': 29,
#  'life': 30,
#  'thing': 31,
#  'know': 32,
#  'drive': 33,
#  'want': 34,
#  'even': 35,
#  'teacher': 36,
#  'say': 37,
#  'day': 38,
#  'give': 39,
#  'new': 40,
#  'class': 41,
#  'project': 42,
#  'phone': 43,
#  'venus': 44,
#  'face': 45,
#  'system': 46,
#  'activity': 47,
#  'president': 48,
#  'reason': 49,
#  'see': 50,
#  'ample': 51,
#  'technology': 52,
#  'change': 53,
#  'important': 54,
#  'believe': 55,
#  'able': 56,
#  'we': 57,
#  'something': 58,
#  'world': 59,
#  'idea': 60,
#  'benefit': 61,
#  'lead': 62,
#  'limit': 63,
# ...
